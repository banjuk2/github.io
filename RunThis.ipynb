# %% [markdown]
# <a href="https://colab.research.google.com/github/banjuk2/github.io/blob/master/RunThis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 코드 실행 결과
#
# >
#
#
# 1) command 출력
# ```
# Simulating C5-2v on k2....
# NumElements:         128
# NumMaxTxChannels:    128
# NumTxElements:       49
# NumActualTxElements: 49 (ChMod: 0)
# Tx Focus Depth [cm]:        10.00
# Tx Steering Angle [deg]:    20.00
# Tx Origin [cm or deg]:      0.00
# Tx Origin Position [cm]:    (0.00, 0.00, 0.00)
# Tx Focus Position [cm]:     (3.42, 0.00, 9.40)
# Tx Frequency [MHz]:  4.00
# Calc. Distance: 100%|██████████| 10201/10201 [00:00<00:00, 12364.77it/s]
# Calc. Pressure: 100%|██████████| 499849/499849 [00:02<00:00, 226378.30it/s]
# Convolving Pressure and Tx Pulse....
# --- 80.74 seconds ---
# ```
# 1) figure1: Beam pattern
#
# >
#
#
# ![image.png](data:image/png;base64,...)
#
#
# 2) figure 2: Tx pulse and response
#
#
# >
#
#
# ![image.png](data:image/png;base64,...)
#
# 4) figure 3: Delay and apodization
#
#
# >
#
#
# ![image.png](data:image/png;base64,...)

# %%
# 모듈 import 
import numpy as np # 선형대수 수치연산 
import scipy.signal as sp # 신호처리 
import matplotlib.pylab as pl # 그래프 플롯 
from matplotlib import animation  

# 모듈 : 사용자 정의 
# TBU

# %%
#%% Input parameter 
TransducerName = 'C5-2v'

TxFrequencyIndex = 17 # 160MHz dual pulser라 freuency 제한적. 
TxNumCycles = 4 
TxWaveformStyle = 1

TxFNum = 4
TxAcceptanceFactor = 1.0 # 뭐에쓰는거지? 
TxAcceptanceAngleDeg = 89
IsChannelModOn = 0 # 0: off 1: on(SC2k mimiking)

TxOriginCmDeg = 0.0 # Lateral Tx ogirin point on aperture surface, Cm for Linear Probe, Deg for Convex Probe

TxFocusDepthCm = 10
TxsteeringAngleDeg = 20
